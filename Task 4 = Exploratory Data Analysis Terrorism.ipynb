# %% [markdown]
# # The Sparks Foundation- GRIP-Data Science and Business Analytics

# %% [markdown]
# # Task 4 : Exploratory Data Analysis-Terrorism

# %% [markdown]
# # Author- Amruta Nangude

# %% [markdown]
# # Dataset Used- Sample Datastore dataset
# Dataset can be downloaded through given link:https://bit.ly/2TK5Xn5

# %% [markdown]
# # Problem Statement for #Task4 :
# i) Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'
#
# ii) As a security/defense analyst, try to find out the hot zone of terrorism.
#
# iii) What all security issues and insights you can derive by EDA?

# %% [markdown]
# # Technical Stack : Sikit Learn, Numpy Array, Seaborn, Pandas, Matplotlib

# %%
# Importing the required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading data from remote link
data = pd.read_csv("globalterrorismdb_0718dist.csv")
print("Data imported successfully")

#print first 5 record from dataset
data.head(10)
# Out:
# Data imported successfully
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
# 5  1.970010e+11   1970       1     1        NaN         0        NaN      217
# 6  1.970010e+11   1970       1     2        NaN         0        NaN      218
# 7  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 8  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 9  1.970010e+11   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# ...

# %%
#print last 5 record from dataset
data.tail(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181681  2.017120e+11   2017      12    31        NaN         0        NaN
# 181682  2.017120e+11   2017      12    31        NaN         0        NaN
# 181683  2.017120e+11   2017      12    31        NaN         0        NaN
# 181684  2.017120e+11   2017      12    31        NaN         0        NaN
# 181685  2.017120e+11   2017      12    31        NaN         0        NaN
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# ...

# %%
#Shape of data
data.shape
# Out:
# (181691, 135)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
data.dtypes
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
#checking statistical description of dataset
print(data.describe())
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#printing columns name
columns=data.columns.tolist()
print(columns)
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %%
#checking for correlation
data.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002705  0.018270  0.091762 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002705  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018270  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091762  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181613 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077851 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175606 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
#checking for null values
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':"Day",'gname':'Group','country_txt':'Country',
                     'region_txt':'Region','provstate':'Province','city':'City','latitude':'Latitude',
                     'longitude':'Longitude','summary':'Summary','attacktype1_txt':'Attacktype',
                     'targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'Killed',
                     'nwound':'Wounded'},inplace = True)

# %%
data = data[['Year','Month','Day','Country','Province','Region','City','Latitude','Longitude',"Attacktype",
             'Killed','Wounded','target1','Summary','Group','Targettype','Weapon','motive']]
data.head()
# Out:
#    Year  Month  Day             Country Province                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      Attacktype  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                  target1 Summary  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot= True)
plt.show()

# %% [markdown]
# # Step 3 : Visualization

# %%
#Attack Type
plt.figure(figsize=(20,10))
sns.countplot(x=data['attacktype1_txt'],order=data['attacktype1_txt'].value_counts().index,palette='flare')
plt.xticks(rotation =90)
plt.xlabel("Targets",fontsize=15)
plt.ylabel("Number of targets",size=15)
plt.title("Name of Attack type",fontsize=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'attacktype1_txt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-bc61d0a44d3b> in <module>
#       1 #Attack Type
# ...

# %%
#Top 10 Weapons used in Terror Attacks
plt.subplots(figsize=(20,10))
sns.barplot(data['Weapon'].value_counts()[:10].index, data['Weapon'].value_counts()[:10].values, palette='colorblind')
plt.title("Top 10 Weapons Used in Terror Attacks", fontsize=24)
plt.xlabel('Weapon Type', fontsize=18)
plt.ylabel('No. Of Weapon Used', fontsize=18)
plt.xticks(rotation = 90)
plt.show()

# %%
#Top 10 Countries With Highest Terror Attacks
plt.subplots(figsize=(20,10))
country = data['Country'].unique()
countries_count = data['Country'].value_counts(dropna = False).sort_index()
sns.barplot(x=country, y=countries_count)
sns.barplot(data['Country'].value_counts()[:10].index,data['Country'].value_counts()[:10].values,palette='Dark2')
plt.title("Top 10 Countries With Highest Terror Attacks", fontsize=24)
plt.xlabel('Countries', fontsize=18)
plt.ylabel('No. of Attacks', fontsize=18)
plt.xticks(rotation=90)
plt.show()

# %%
#Top 10 Cities With Highest Terror Attacks
plt.subplots(figsize=(20,10))
sns.barplot(data['City'].value_counts()[:10].index,data['City'].value_counts()[:10].values,palette= 'nipy_spectral')
plt.title("Top 10 Cities With Highest Terror Attacks", fontsize=24)
plt.xlabel('Cities', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.xticks(rotation = 90)
plt.show()

# %%
#Terrorist Activities By Region In Each Year
plt.subplots(figsize=(12,7))
sns.kdeplot(data['Year'], hue=data['Region'])
plt.title('Terrorist Activities By Region', fontsize=24)
plt.xlabel('Year', fontsize=18)
plt.ylabel('Frequency Of Attacks', fontsize=18)
plt.xticks(rotation = 90)
plt.show()

# %%
#Total Deaths in Terror Attacks Year wise
plt.subplots(figsize=(20,10))
data.groupby(['Year'])['Killed'].sum().sort_values(ascending = False).head(20).plot(kind = 'pie')
plt.title("Total Deaths in Year", fontsize=24)
plt.xlabel('Attack Year', fontsize=18)
plt.ylabel('No. Of Deaths', fontsize=18)
plt.xticks(rotation = 90)
plt.show()

# %%
#Top 10 Terrorist Organisation with Highest Terror Attacks
plt.figure(figsize = (12,7))
sns.barplot(x = data['Group'].value_counts()[1:11].values, y = data['Group'].value_counts()[1:11].index,palette='magma')
plt.title('Top 10 Terrorist Organisation with Highest Terror Attacks', fontsize=24)
plt.ylabel('Terror Group Name', fontsize=18)
plt.xlabel('Number of Attacks', fontsize=18)
plt.xticks(rotation= 90)
plt.show()

# %%
df=data[['Attacktype','Killed']]
df=df.groupby(['Attacktype','Killed'],axis=0).sum().sort_values('Killed',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
#                     Attacktype  Killed
# 0  Hostage Taking (Kidnapping)  1570.0
# 1                    Hijacking  1384.0
# 2                    Hijacking  1383.0
# 3                Armed Assault  1180.0
# 4  Hostage Taking (Kidnapping)   953.0
# 5                Armed Assault   670.0
# 6            Bombing/Explosion   588.0
# 7                Armed Assault   518.0
# 8  Hostage Taking (Kidnapping)   517.0
# 9  Hostage Taking (Kidnapping)   433.0

# %% [markdown]
# # Conclusion :

# %% [markdown]
# 1: Top Country with the most attacks: Iraq
#
# 2: City with the most number of attacks: Baghdad
#
# 3: Region with the most attacks: Middle East & North Africa
#
# 4: Year with the most attacks: 2014
#
# 5: Group with the most attacks: Taliban
#
# 6: Most Number of Attack Types: Bombing/Explosion

# %% [markdown]
# # Thank You..!!!
